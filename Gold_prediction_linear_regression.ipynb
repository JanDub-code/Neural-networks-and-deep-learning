# %%
from sklearn.linear_model import LinearRegression
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("monthly_csv.csv")
data.head()

# numpy field from 0 do 833 by months from 1950
x = np.arange(len(data))
y = data["Price"].to_numpy()

x.shape

x = x.reshape(-1, 1)
y = y.reshape(-1, 1)

x.shape, y.shape

reg = LinearRegression()
reg.fit(x, y)

reg.score(x, y)

plt.plot(x, reg.predict(x))
plt.scatter(x, y, c="r")

#prediction for 1.7.2025
reg.predict([[906]]).item()
# Out:
# 1126.481982068847
